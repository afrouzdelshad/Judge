# %%
import json

with open("config.json") as f:
    llms = json.load(f)["llms"]

for name, info in llms.items():
    print(f"{name} -> {info['provider']}")

# %%
from LLM_factory import chat_with

model = "claude-opus-4-8"  # pick any model name printed above
system_prompt = "You are a concise, helpful assistant."
user_prompt = "In one sentence, say hello and name the model you are."

print(chat_with(model, system_prompt, user_prompt))
